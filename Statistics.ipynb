# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
df=pd.read_csv("C:\\Users\\USER\\Desktop\\desktop\\Final Year project\\Data_Analysis_project\\OI\\withoout 18\\EngineeringRanking.csv")
df
# Out:
#      Institute Id                                     Institute Name  \
# 0     IR-E-U-0456              Indian Institute of Technology Madras
# 1     IR-E-I-1074               Indian Institute of Technology Delhi
# 2     IR-E-U-0306              Indian Institute of Technology Bombay
# 3     IR-E-I-1075              Indian Institute of Technology Kanpur
# 4     IR-E-U-0573           Indian Institute of Technology Kharagpur
# 5     IR-E-U-0560             Indian Institute of Technology Roorkee
# 6     IR-E-U-0053            Indian Institute of Technology Guwahati
# 7     IR-E-U-0013           Indian Institute of Technology Hyderabad
# 8     IR-E-U-0467   National Institute of Technology Tiruchirappalli
# 9     IR-E-U-0237         National Institute of Technology Karnataka
# 10    IR-E-U-0205  Indian Institute of Technology (Indian School ...
# 11    IR-E-U-0490                    Vellore Institute of Technology
# 12    IR-E-U-0273              Indian Institute of Technology Indore
# ...

# %%
#### First lets compare TLR first

# %%
TLR_21 = df[['TLR_21']]
TLR_20 = df[['TLR_20']]
TLR_19 = df[['TLR_19']]

# %%
Year=[2021,2020,2019]
TLR_mean=[TLR_21.mean(),TLR_20.mean(),TLR_19.mean()]

# %%
# Out:
# [TLR_21    61.062986
#  dtype: float64, TLR_20    60.616042
#  dtype: float64, TLR_19    59.244653
#  dtype: float64]

# %%
###Lets show the increase in TLR score by each institute from each year

# %%
Sub1=np.subtract(TLR_20, TLR_19) 
Sub1
# Out:
#      TLR_20
# 0      1.87
# 1      4.99
# 2      1.88
# 3      7.15
# 4      4.18
# 5      2.16
# 6      0.49
# 7      3.60
# 8      3.75
# 9      9.45
# 10     0.40
# 11     2.14
# 12     4.23
# 13     3.73
# 14     0.37
# 15     0.33
# 16     1.45
# 17     2.27
# 18     4.39
# 19     3.07
# 20     3.17
# 21     5.19
# 22    -3.56
# 23     7.58
# 24    -0.45
# 25     1.92
# 26     2.89
# 27     1.71
# 28    -1.09
# 29     1.19
# ..      ...
# 114    2.26
# 115   -4.68
# 116    4.19
# 117   -1.18
# 118   -0.29
# 119    2.60
# 120    1.09
# 121    1.70
# 122    3.14
# 123   -2.82
# 124    3.15
# 125    0.74
# 126   -0.05
# 127    2.26
# 128    4.55
# 129   -7.37
# 130    4.25
# 131   -0.17
# 132   -2.64
# 133    2.10
# 134    4.36
# 135    0.65
# 136   -3.97
# 137   -0.45
# 138    0.16
# 139   -8.44
# 140    3.29
# 141    2.67
# 142    0.02
# 143   -4.95
#
# [144 rows x 1 columns]

# %%
name=df[['Institute Name']]

# %%
Sub2=np.subtract(TLR_21, TLR_20)

# %%
Sub2
# Out:
#      TLR_21
# 0      0.05
# 1      0.97
# 2     -1.68
# 3      0.49
# 4      3.19
# 5      2.07
# 6     -3.79
# 7      0.09
# 8     -2.11
# 9      4.22
# 10     5.27
# 11     4.62
# 12    -3.67
# 13    -4.94
# 14     7.32
# 15     1.09
# 16     1.67
# 17     2.24
# 18    -2.17
# 19    -1.71
# 20    -1.66
# 21    -5.50
# 22    -1.06
# 23    -3.05
# 24    -1.96
# 25    14.47
# 26    -1.51
# 27    -2.76
# 28    -2.89
# 29     1.21
# ..      ...
# 114   -1.24
# 115    4.35
# 116    1.24
# 117    0.19
# 118    1.97
# 119   -1.88
# 120    1.11
# 121   -0.12
# 122    5.30
# 123   -0.44
# 124    0.76
# 125   -0.88
# 126   -0.52
# 127    2.76
# 128   -1.01
# 129    6.92
# 130    0.18
# 131  -11.38
# 132    0.00
# 133   -0.61
# 134   -2.22
# 135   -3.93
# 136   -2.15
# 137   -5.05
# 138    2.44
# 139    0.63
# 140    1.82
# 141    0.27
# 142   -1.86
# 143   -0.67
#
# [144 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( Sub2)

# %%
plt.plot(Sub1)

# %%
# Out:
# [     TLR_20
#  0      1.87
#  1      4.99
#  2      1.88
#  3      7.15
#  4      4.18
#  5      2.16
#  6      0.49
#  7      3.60
#  8      3.75
#  9      9.45
#  10     0.40
#  11     2.14
#  12     4.23
#  13     3.73
#  14     0.37
#  15     0.33
#  16     1.45
#  17     2.27
#  18     4.39
#  19     3.07
#  20     3.17
#  21     5.19
#  22    -3.56
#  23     7.58
#  24    -0.45
#  25     1.92
#  26     2.89
#  27     1.71
#  28    -1.09
#  29     1.19
#  ..      ...
#  114    2.26
#  115   -4.68
#  116    4.19
#  117   -1.18
#  118   -0.29
#  119    2.60
#  120    1.09
#  121    1.70
#  122    3.14
#  123   -2.82
#  124    3.15
#  125    0.74
#  126   -0.05
#  127    2.26
#  128    4.55
#  129   -7.37
#  130    4.25
#  131   -0.17
#  132   -2.64
#  133    2.10
#  134    4.36
#  135    0.65
#  136   -3.97
#  137   -0.45
#  138    0.16
#  139   -8.44
#  140    3.29
#  141    2.67
#  142    0.02
#  143   -4.95
#
#  [144 rows x 1 columns],      TLR_21
#  0      0.05
# ...

# %%
RPC_21 = df[['RPC_21']]
RPC_20 = df[['RPC_20']]
RPC_19 = df[['RPC_19']]
OI_21 = df[['OI_21']]
OI_20 = df[['OI_20']]
OI_19 = df[['OI_19']]
GO_21 = df[['GO_21']]
GO_20 = df[['GO_20']]
GO_19 = df[['GO_19']]
PR_21 = df[['Perception_21']]
PR_20 = df[['Perception_20']]
PR_19 = df[['Perception_19']]

# %%
Rank_21 = df[['Rank_21']]
Rank_20 = df[['Rank_20']]
Rank_19 = df[['Rank_19']]
Score_21 = df[['Score_21']]
Score_20 = df[['Score_20']]
Score_19 = df[['Score_19']]
